# %%
from google.colab import drive
drive.mount('/content/drive')
# !pip install ultralytics
# !pip install pyyaml
# !pip install matplotlib seaborn
# !pip install opencv-python-headless
# %cd /content/drive/MyDrive/HackByte_Dataset
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 30.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 84.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 71.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 48.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.8 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python train.py
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Configuration loaded from: /content/drive/.shortcut-targets-by-id/1i2Se4cR2JTtjkgrs5Uehmr-6O43Vv1EK/HackByte_Dataset/yolo_params.yaml
# Training for 100 epochs with batch size 16
# Image size: 640px
# Learning rate: 0.01
# Saving to: runs//exp_space
# Starting new training with model: yolov8l.pt
# Ultralytics 8.3.159 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/HackByte_Dataset/runs/exp_space/results.csv')
df.tail(1)
# Out:
#      epoch     time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 244    100  9417.94         0.67195          0.3568         1.03473
#
#      metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 244               0.97797            0.88564           0.94725
#
#      metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 244              0.78276       0.72234       0.40768       1.00922  0.000015
#
#        lr/pg1    lr/pg2
# 244  0.000015  0.000015

# %%
# !python predict.py
# Out:
# Loading model from: /content/drive/.shortcut-targets-by-id/1i2Se4cR2JTtjkgrs5Uehmr-6O43Vv1EK/HackByte_Dataset/runs/exp_space/weights/best.pt
# Saving evaluation results to: /content/drive/.shortcut-targets-by-id/1i2Se4cR2JTtjkgrs5Uehmr-6O43Vv1EK/HackByte_Dataset/reports/eval_exp_space
# Running validation with test-time augmentation...
# Ultralytics 8.3.159 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 112 layers, 43,608,921 parameters, 0 gradients, 164.8 GFLOPs
# val: Fast image access ✅ (ping: 0.5±0.1 ms, read: 430.1±89.7 MB/s, size: 3108.6 KB)
# val: Scanning /content/drive/.shortcut-targets-by-id/1i2Se4cR2JTtjkgrs5Uehmr-6O43Vv1EK/HackByte_Dataset/data/test/labels.cache... 400 images, 0 backgrounds, 0 corrupt: 100% 400/400 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 25/25 [00:26<00:00,  1.08s/it]
# ...

# %%
# !python visualize.py
# Out:
# Creating dataset distribution visualization...
# Creating model performance visualizations...
# Creating sample predictions visualization...
# Creating confusion matrix visualization...
# Copied confusion matrix from /content/drive/.shortcut-targets-by-id/1i2Se4cR2JTtjkgrs5Uehmr-6O43Vv1EK/HackByte_Dataset/reports/eval_exp_space/plots/confusion_matrix.png
# Creating precision-recall curves...
# No PR curve data found. Attempting to create it...
# Ultralytics 8.3.159 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 112 layers, 43,608,921 parameters, 0 gradients, 164.8 GFLOPs
# val: Fast image access ✅ (ping: 0.4±0.0 ms, read: 433.4±197.4 MB/s, size: 3109.2 KB)
# val: Scanning /content/drive/.shortcut-targets-by-id/1i2Se4cR2JTtjkgrs5Uehmr-6O43Vv1EK/HackByte_Dataset/data/test/labels.cache... 400 images, 0 backgrounds, 0 corrupt: 100% 400/400 [00:00<?, ?it/s]
# ...

# %%
# Install necessary packages
# !pip install streamlit pyngrok
# !pip install ultralytics matplotlib seaborn
from pyngrok import ngrok

ngrok.set_auth_token("2yogH6W9GgeI4c0896kHfhBo3ov_xU8cRL4TpF16FGDLFFdy")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 90.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 119.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 7.3 MB/s eta 0:00:00
# ...

# %%
# Setup and run the Streamlit app with ngrok
import os
from pyngrok import ngrok
import time

# Define model path - uses the path you specified
MODEL_PATH = "/content/drive/MyDrive/HackByte_Dataset/runs/exp_space/weights/best.pt"

# Verify if model exists, if not look in other common locations
if not os.path.exists(MODEL_PATH):
    print(f"Model not found at {MODEL_PATH}, searching in alternative locations...")
    # List of possible locations
    possible_locations = [
        "/content/runs/exp_space/weights/best.pt",
        "/content/runs/train/exp_space/weights/best.pt",
        "/content/drive/MyDrive/space_station/runs/exp_space/weights/best.pt",
        "/content/drive/MyDrive/HackByte_Dataset/yolov8l.pt", # Your specific model path
        "/content/HackByte_Dataset/runs/exp_space/weights/best.pt"
    ]

    for loc in possible_locations:
        if os.path.exists(loc):
            MODEL_PATH = loc
            print(f"Found model at: {MODEL_PATH}")
            break

# Set the environment variable for the Streamlit app
os.environ["MODEL_PATH"] = MODEL_PATH
print(f"Using model at: {MODEL_PATH}")

# Start ngrok tunnel - using port 8505 as in your code
public_url = ngrok.connect(8505)
print(f"Streamlit app URL: {public_url}")
# Out:
# Using model at: /content/drive/MyDrive/HackByte_Dataset/runs/exp_space/weights/best.pt
# Streamlit app URL: NgrokTunnel: "https://3b73-35-247-37-61.ngrok-free.app" -> "http://localhost:8505"

# %%
# Run the Streamlit app
# !streamlit run streamlit_direct_ngrok.py --server.port 8505 &>/dev/null & sleep 3
print("Streamlit app is running!")
print(f"Access your app at: {public_url}")
# Out:
# Streamlit app is running!
# Access your app at: NgrokTunnel: "https://3b73-35-247-37-61.ngrok-free.app" -> "http://localhost:8505"
